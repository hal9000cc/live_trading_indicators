# %%
import live_trading_indicators as lti

indicator_params = {
    'CCI': {'period': 14},
    'EMA': {'period': 14},
    'MA': {'period': 21},
    'SMA': {'period': 14},
    'MACD': {'period_short': 12, 'period_long': 26, 'period_signal': 9},
    'RSI': {'period': 14},
    'TEMA': {'period': 21},
    'TRIX': {'period': 13},
    'VWMA': {'period': 14}
}

indicators = lti.Indicators('binance', 20220625, 20220710)
for indicator_name in lti.indicators_list():
    if indicator_name == 'VolumeClusters':
        continue
    indicator = indicators.get_indicator(indicator_name)
    params = indicator_params.get(indicator_name, {})
    out = indicator('um/btcusdt', '1h', 20220701, 20220710, **params)
    out.show()
# Out:
# 2023-01-02 06:33:51:root:161556:175 INFO Download using binance symbol btcusdt timeframe 1h from 2022-06-25T00:00:00.000, bars: 145
# 2023-01-02 06:33:54:matplotlib.legend:161556:1217 WARNING No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2023-01-02 06:33:54:matplotlib.legend:161556:1217 WARNING No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2023-01-02 06:33:55:matplotlib.legend:161556:1217 WARNING No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2023-01-02 06:33:55:matplotlib.legend:161556:1217 WARNING No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2023-01-02 06:33:57:root:161556:175 INFO Download using binance symbol btcusdt timeframe 1m from 2022-06-25T00:00:00.000, bars: 1500
# 2023-01-02 06:33:58:root:161556:175 INFO Download using binance symbol btcusdt timeframe 1m from 2022-06-26T01:00:00.000, bars: 1500
# 2023-01-02 06:33:59:root:161556:175 INFO Download using binance symbol btcusdt timeframe 1m from 2022-06-27T02:00:00.000, bars: 1500
# 2023-01-02 06:34:00:root:161556:175 INFO Download using binance symbol btcusdt timeframe 1m from 2022-06-28T03:00:00.000, bars: 1500
# 2023-01-02 06:34:01:root:161556:175 INFO Download using binance symbol btcusdt timeframe 1m from 2022-06-29T04:00:00.000, bars: 1500
# 2023-01-02 06:34:02:root:161556:175 INFO Download using binance symbol btcusdt timeframe 1m from 2022-06-30T05:00:00.000, bars: 1141
# 2023-01-02 06:34:03:root:161556:175 INFO Download using binance symbol btcusdt timeframe 1m from 2022-07-10T00:00:00.000, bars: 1441
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_161556/783423276.py in <module>
#      20     params = indicator_params.get(indicator_name, {})
#      21     out = indicator('um/btcusdt', '1h', 20220701, 20220710, **params)
# ---> 22     out.show()
#
# ~/.local/lib/python3.10/site-packages/live_trading_indicators/indicator_data.py in show(self)
#     646
#     647     def show(self):
# --> 648         fig = self.plot()
#     649         fig.show()
#     650         return fig
#
# ~/.local/lib/python3.10/site-packages/live_trading_indicators/indicator_data.py in plot(self)
#     643
#     644     def plot(self):
# --> 645         return extra_module('.plotting').indicator_data_plot(self)
#     646
#     647     def show(self):
#
# ~/.local/lib/python3.10/site-packages/live_trading_indicators/plotting.py in indicator_data_plot(indicator_data)
#     106                 values = indicator_data.data[value_name]
#     107
# --> 108             plot_indicator(ax, timeframe, time, value_name, values, chart_type)
#     109
#     110     need_legend = False
#
# ~/.local/lib/python3.10/site-packages/live_trading_indicators/plotting.py in plot_indicator(axis, timeframe, time, name, values, chart_type)
#     188
#     189     elif chart_type == 'bar_level':
# --> 190         marker = MarkerStyle('_').scaled(0.7)
#     191         axis.scatter(time, values, marker=marker, linewidths=1, label=name)
#     192
#
# AttributeError: 'MarkerStyle' object has no attribute 'scaled'
